# %%
import jax
import flax
import optax
from jax import lax, random, value_and_grad, numpy as jnp
from jax import random, grad, vmap, hessian, jacfwd, jit
from jax import config
from jax.tree_util import Partial
from flax import linen as nn
import jax_dataloader as jd

import time
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colors

import torch
from torch.utils.data import Dataset

import os
from tqdm.auto import tqdm

#os.environ['CUDA_VISIBLE_DEVICES'] = '1'
config.update("jax_enable_x64", True)
os.environ['XLA_PYTHON_CLIENT_ALLOCATOR'] = 'cuda_async'
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE'] = 'true' # default is true, 90% of GPU VRAM preallocated

# %%
DATA_DIR = Path.cwd().parent.parent / "data" / "darcy_flow_data" 
FILE_PATH = DATA_DIR / "2D_DarcyFlow_beta10.0_Train.hdf5"

# %%
import h5py

sample_idx = 3
bc_sample = 0.0 # u(x) = 0 on the boundary
beta = 10.0     # Force term f(x)

with h5py.File(FILE_PATH, 'r') as f:
    x_coords = np.array(f['x-coordinate'][:])
    y_coords = np.array(f['y-coordinate'][:])
    a_sample = jnp.array(f['nu'][sample_idx])
    u_raw = jnp.array(f['tensor'][sample_idx])

# Squeeze out the extra dimension
u_sample = u_raw.squeeze()

# Flatten for network
a_flat = a_sample.reshape(-1, 1)
u_flat = u_sample.reshape(-1, 1)

print(f"Spatial Field 'a' Shape: {a_flat.shape}")
print(f"Solution 'u' Shape: {u_flat.shape}")
# Out:
# E0717 22:52:47.559200  108062 cuda_executor.cc:1526] Could not get kernel mode driver version: (INVALID_ARGUMENT: Version does not match the format X.Y.Z)
# E0717 22:52:47.628830  107951 cuda_executor.cc:1526] Could not get kernel mode driver version: (INVALID_ARGUMENT: Version does not match the format X.Y.Z)
# Spatial Field 'a' Shape: (16384, 1)
# Solution 'u' Shape: (16384, 1)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plotting 'a' (the spatial dependent function)
im1 = axes[0].imshow(a_sample.T, origin='lower', cmap='rainbow', extent=[0, 1, 0, 1])
fig.colorbar(im1, ax=axes[0])
axes[0].set_title(f'Spatial Field (a) | BC: {bc_sample:.4f}', fontsize='x-large')
axes[0].set_xlabel('x-dim')
axes[0].set_ylabel('y-dim')

# Plotting 'u' (the solution)
im2 = axes[1].imshow(u_sample.T, origin='lower', cmap='rainbow', extent=[0, 1, 0, 1])
fig.colorbar(im2, ax=axes[1])
axes[1].set_title('Simulation Ground Truth (u)', fontsize='x-large')
axes[1].set_xlabel('x-dim')
axes[1].set_ylabel('y-dim')

plt.tight_layout()
plt.show()

# %%
from scipy.ndimage import gaussian_filter

nx = len(x_coords) 
ny = len(y_coords) 
X, Y = np.meshgrid(x_coords, y_coords, indexing='ij')

x = jnp.array(X.reshape(-1, 1))
y = jnp.array(Y.reshape(-1, 1))

x_l, x_u = float(np.min(x_coords)), float(np.max(x_coords)) 
y_l, y_u = float(np.min(y_coords)), float(np.max(y_coords)) 

bc_left = (x == x_l).flatten() 
bc_right = (x == x_u).flatten()
bc_bottom = (y == y_l).flatten()
bc_top = (y == y_u).flatten()
bc_all = bc_left | bc_right | bc_bottom | bc_top 

# 1. Smooth the discontinuous 'a' field
a_sample_np = np.array(a_sample)
a_sample_smoothed = jnp.array(gaussian_filter(a_sample_np, sigma=1))

# 2. Calculate spatial gradients on the SMOOTHED field
h_x = x_coords[1] - x_coords[0]
h_y = y_coords[1] - y_coords[0]
da_dx, da_dy = jnp.gradient(a_sample_smoothed, h_x, h_y)

a_flat_smooth = a_sample_smoothed.reshape(-1, 1)
a_x_flat = da_dx.reshape(-1, 1)
a_y_flat = da_dy.reshape(-1, 1)

# 3. Extract boundaries
x_bc = x[bc_all]
y_bc = y[bc_all]
bc_val_array = jnp.ones_like(x_bc) * bc_sample

# 4. MASKING LOGIC: Find flat regions
grad_magnitude = jnp.sqrt(a_x_flat**2 + a_y_flat**2)
flat_regions_mask = (grad_magnitude < 0.01).flatten() 

# Combine masks: Must be inside the domain AND flat
valid_mask = (~bc_all)

# 5. Extract only the VALID interior points
x_valid = x[valid_mask]
y_valid = y[valid_mask]
a_valid = a_flat_smooth[valid_mask]
a_x_valid = a_x_flat[valid_mask]
a_y_valid = a_y_flat[valid_mask]
u_valid = u_flat[valid_mask]

print(f"Total grid points: {x.shape[0]}")
print(f"Boundary points: {x_bc.shape[0]}")
print(f"Valid (flat) interior points extracted: {x_valid.shape[0]}")
# Out:
# Total grid points: 16384
# Boundary points: 508
# Valid (flat) interior points extracted: 15876

# %%
epochs = 600
M = 512 
chunk_size = 256 
hidden_layers = [256, 256, 256, 256] 
total_features = hidden_layers[-1]

sigma = 1
tik_reg_fixed = 1e-8
matrix_bc_weight = 1e2
pde_loss_weight = 1.0
bc_loss_weight = 1e2
data_loss_weight = 0

rff_key = jax.random.PRNGKey(99)
B_matrix_base = jax.random.normal(rff_key, (2, M))

class FeatureExtractor(nn.Module):
    hidden_layers: list
    B_matrix_base: jnp.ndarray 
    
    @nn.compact
    def __call__(self, x_in, y_in):    
        v = jnp.concatenate([x_in, y_in])
        proj = 2.0 * jnp.pi * jnp.dot(v, self.B_matrix_base * sigma)
        h = jnp.concatenate([jnp.sin(proj), jnp.cos(proj)])

        for size in self.hidden_layers:
            h = nn.Dense(size, kernel_init=nn.initializers.he_normal())(h)
            h = nn.tanh(h) 
        return h 

model = FeatureExtractor(hidden_layers=hidden_layers, B_matrix_base=B_matrix_base)
key = jax.random.PRNGKey(0)
params = model.init(key, jnp.array([0.0]), jnp.array([0.0]))

def get_f(params, x_val, y_val):
    return model.apply(params, x_val, y_val)

def get_f_dir(params, x_val, y_val):
    f_x = jacfwd(get_f, argnums=1)(params, x_val, y_val)
    f_y = jacfwd(get_f, argnums=2)(params, x_val, y_val)
    f_xx = jacfwd(jacfwd(get_f, argnums=1), argnums=1)(params, x_val, y_val)
    f_yy = jacfwd(jacfwd(get_f, argnums=2), argnums=2)(params, x_val, y_val)
    
    f_x = jnp.squeeze(f_x, axis=-1)
    f_y = jnp.squeeze(f_y, axis=-1)
    f_xx = jnp.squeeze(f_xx, axis=(-1, -2))
    f_yy = jnp.squeeze(f_yy, axis=(-1, -2))
    return f_x, f_y, f_xx, f_yy

def get_f_chunk(params, x_val, y_val, start_idx, end_idx):
    f = model.apply(params, x_val, y_val)
    return lax.dynamic_slice(f, (start_idx,), (end_idx - start_idx,))

def get_f_dir_chunk(params, x_val, y_val, start_idx, end_idx):
    f_x_chunk = jacfwd(get_f_chunk, argnums=1)(params, x_val, y_val, start_idx, end_idx)
    f_y_chunk = jacfwd(get_f_chunk, argnums=2)(params, x_val, y_val, start_idx, end_idx)
    f_xx_chunk = jacfwd(jacfwd(get_f_chunk, argnums=1), argnums=1)(params, x_val, y_val, start_idx, end_idx)
    f_yy_chunk = jacfwd(jacfwd(get_f_chunk, argnums=2), argnums=2)(params, x_val, y_val, start_idx, end_idx)
    
    f_x_chunk = jnp.squeeze(f_x_chunk, axis=-1)
    f_y_chunk = jnp.squeeze(f_y_chunk, axis=-1)
    f_xx_chunk = jnp.squeeze(f_xx_chunk, axis=(-1, -2))
    f_yy_chunk = jnp.squeeze(f_yy_chunk, axis=(-1, -2))
    return f_x_chunk, f_y_chunk, f_xx_chunk, f_yy_chunk

def get_u_dir(params, x_val, y_val, w_current):
    f_x, f_y, f_xx, f_yy = get_f_dir(params, x_val, y_val)
    u_x = jnp.dot(f_x, w_current)
    u_y = jnp.dot(f_y, w_current)
    u_xx = jnp.dot(f_xx, w_current)
    u_yy = jnp.dot(f_yy, w_current)
    return u_x, u_y, u_xx, u_yy

f_spatial_vmap = vmap(get_f, in_axes=(None, 0, 0))
f_dir_spatial_vmap = vmap(get_f_dir, in_axes=(None, 0, 0))
f_chunk_spatial_vmap = vmap(get_f_chunk, in_axes=(None, 0, 0, None, None))
f_dir_chunk_spatial_vmap = vmap(get_f_dir_chunk, in_axes=(None, 0, 0, None, None))
u_dir_spatial_vmap = vmap(get_u_dir, in_axes=(None, 0, 0, None))

# %%
lr_schedule = optax.cosine_decay_schedule(init_value=1e-3, decay_steps=epochs, alpha=0.1)
optimizer = optax.adamw(learning_rate=lr_schedule, weight_decay=1e-4)

def get_A_and_b(params, x_pde, y_pde, a_pde, a_x_pde, a_y_pde, x_bc, y_bc, bc_val_arr, total_features, chunk_size):
    A_chunks = []
    
    for start_idx in range(0, total_features, chunk_size):
        end_idx = min(start_idx + chunk_size, total_features)
        
        f_x, f_y, f_xx, f_yy = f_dir_chunk_spatial_vmap(params, x_pde, y_pde, start_idx, end_idx)
        A_pde_chunk = -(a_x_pde * f_x + a_y_pde * f_y + a_pde * (f_xx + f_yy))
        
        f_bc_chunk = f_chunk_spatial_vmap(params, x_bc, y_bc, start_idx, end_idx)
        A_bc_chunk = f_bc_chunk * jnp.sqrt(matrix_bc_weight)
        
        A_chunk = jnp.vstack([A_pde_chunk, A_bc_chunk])
        A_chunks.append(A_chunk)
        
    A_full = jnp.hstack(A_chunks)
    
    b_pde = jnp.ones_like(a_pde) * beta
    b_bc = bc_val_arr * jnp.sqrt(matrix_bc_weight)
    b_full = jnp.vstack([b_pde, b_bc])
    
    return A_full, b_full

@jax.jit(static_argnames=['total_features', 'chunk_size'])
def solve_w(params, x_pde, y_pde, a_pde, a_x_pde, a_y_pde, x_bc, y_bc, bc_val_arr, total_features, chunk_size):
    A, b = get_A_and_b(params, x_pde, y_pde, a_pde, a_x_pde, a_y_pde, x_bc, y_bc, bc_val_arr, total_features, chunk_size)
    AtA = A.T @ A + tik_reg_fixed * jnp.eye(total_features)
    Atb = A.T @ b
    return jax.scipy.linalg.solve(AtA, Atb, assume_a='pos')

def compute_all_losses(params, x_batch, y_batch, a_batch, a_x_batch, a_y_batch, x_bc, y_bc, bc_val_arr, u_batch):
    w_current = solve_w(params, x_batch, y_batch, a_batch, a_x_batch, a_y_batch, x_bc, y_bc, bc_val_arr, total_features, chunk_size)
    
    u_x, u_y, u_xx, u_yy = u_dir_spatial_vmap(params, x_batch, y_batch, w_current)
    laplacian_u = u_xx + u_yy
    
    f_interior = f_spatial_vmap(params, x_batch, y_batch)
    u_pred_interior = jnp.dot(f_interior, w_current)
    
    # Darcy Flow PDE Residual
    pde_residual = -(a_x_batch * u_x + a_y_batch * u_y + a_batch * laplacian_u) - beta
    
    f_bc_vals = f_spatial_vmap(params, x_bc, y_bc)
    u_bc_pred = jnp.dot(f_bc_vals, w_current)
    
    loss_pde_unscaled = jnp.mean(pde_residual ** 2)
    loss_bc_unscaled = jnp.mean((u_bc_pred - bc_val_arr) ** 2)
    loss_data_unscaled = jnp.mean((u_pred_interior - u_batch) ** 2)
    
    loss_pde_scaled = loss_pde_unscaled * pde_loss_weight
    loss_bc_scaled = loss_bc_unscaled * bc_loss_weight
    loss_data_scaled = loss_data_unscaled * data_loss_weight
    
    aux_unscaled = (loss_pde_unscaled, loss_bc_unscaled, loss_data_unscaled)
    return (loss_pde_scaled, loss_bc_scaled, loss_data_scaled), aux_unscaled

@jax.jit(static_argnames=['total_features', 'chunk_size'])
def update_network(params, opt_state, x_batch, y_batch, a_batch, a_x_batch, a_y_batch, x_bc, y_bc, bc_val_arr, u_batch, total_features, chunk_size):
    # Vector-Jacobian Product to extract individual gradient norms
    loss_tuple, vjp_fn, aux_unscaled = jax.vjp(
        lambda p: compute_all_losses(p, x_batch, y_batch, a_batch, a_x_batch, a_y_batch, x_bc, y_bc, bc_val_arr, u_batch),
        params,
        has_aux=True
    )
    
    l_pde_scaled, l_bc_scaled, l_data_scaled = loss_tuple
    
    # Pull gradients for each loss individually to monitor the "seesaw"
    pde_grads = vjp_fn((1.0, 0.0, 0.0))[0]
    bc_grads = vjp_fn((0.0, 1.0, 0.0))[0]
    data_grads = vjp_fn((0.0, 0.0, 1.0))[0]
    total_grads = vjp_fn((1.0, 1.0, 1.0))[0] # Sum of all gradients
    
    total_loss = l_pde_scaled + l_bc_scaled + l_data_scaled
    
    # Update network
    updates, opt_state = optimizer.update(total_grads, opt_state, params=params)
    new_params = optax.apply_updates(params, updates)
    
    # Calculate global norms for logging
    grad_norms = (
        optax.global_norm(total_grads),
        optax.global_norm(pde_grads),
        optax.global_norm(bc_grads),
        optax.global_norm(data_grads)
    )
    
    return new_params, opt_state, total_loss, aux_unscaled, grad_norms

# %%
opt_state = optimizer.init(params)
rng = jax.random.PRNGKey(42)

total_valid_points = x_valid.shape[0]
actual_batch_size = 15000 

history_total = []
history_pde = []
history_bc = []
history_data = []

for epoch in tqdm(range(epochs), desc="End-to-End PINN Training"):
    rng, shuffle_key = jax.random.split(rng)
    
    batch_idx = jax.random.choice(shuffle_key, total_valid_points, shape=(actual_batch_size,), replace=True)
    
    x_chunk = x_valid[batch_idx]
    y_chunk = y_valid[batch_idx]
    a_chunk = a_valid[batch_idx]
    a_x_chunk = a_x_valid[batch_idx]
    a_y_chunk = a_y_valid[batch_idx]
    u_chunk = u_valid[batch_idx]
    
    # Pass 'bc_val_array' and 'u_chunk' cleanly to match the original architecture
    params, opt_state, loss, (l_pde, l_bc, l_data), norms = update_network(
        params, opt_state, x_chunk, y_chunk, a_chunk, a_x_chunk, a_y_chunk, x_bc, y_bc, bc_val_array, u_chunk, total_features, chunk_size
    )
    
    history_total.append(float(loss))
    history_pde.append(float(l_pde))
    history_bc.append(float(l_bc))
    history_data.append(float(l_data))
    
    if epoch % 10 == 0:
        g_tot, g_pde, g_bc, g_data = norms
        print(f"Epoch {epoch:<3} | Tot Loss (scaled): {loss:.3e} | PDE(un): {l_pde:.3e} | BC(un): {l_bc:.3e} | Data(un): {l_data:.3e}")
        print(f"            └─ Grad Norms => Tot: {g_tot:.3e} | PDE: {g_pde:.3e} | BC: {g_bc:.3e} | Data: {g_data:.3e}")
# Out:
# End-to-End PINN Training:   0%|          | 0/600 [00:00<?, ?it/s]
# Epoch 0   | Tot Loss (scaled): 8.225e+01 | PDE(un): 8.049e+01 | BC(un): 1.762e-02 | Data(un): 8.785e+00
#             └─ Grad Norms => Tot: 1.967e+02 | PDE: 2.020e+02 | BC: 9.974e+01 | Data: 0.000e+00
# Epoch 10  | Tot Loss (scaled): 4.556e+01 | PDE(un): 4.368e+01 | BC(un): 1.884e-02 | Data(un): 4.374e+00
#             └─ Grad Norms => Tot: 1.338e+02 | PDE: 1.513e+02 | BC: 8.846e+01 | Data: 0.000e+00
# Epoch 20  | Tot Loss (scaled): 3.000e+01 | PDE(un): 2.816e+01 | BC(un): 1.841e-02 | Data(un): 2.570e+00
#             └─ Grad Norms => Tot: 1.346e+02 | PDE: 1.385e+02 | BC: 7.372e+01 | Data: 0.000e+00
# Epoch 30  | Tot Loss (scaled): 2.071e+01 | PDE(un): 1.903e+01 | BC(un): 1.671e-02 | Data(un): 1.573e+00
#             └─ Grad Norms => Tot: 2.084e+02 | PDE: 2.113e+02 | BC: 7.443e+01 | Data: 0.000e+00
# Epoch 40  | Tot Loss (scaled): 1.479e+01 | PDE(un): 1.313e+01 | BC(un): 1.663e-02 | Data(un): 8.308e-01
#             └─ Grad Norms => Tot: 2.079e+02 | PDE: 1.875e+02 | BC: 9.745e+01 | Data: 0.000e+00
# Epoch 50  | Tot Loss (scaled): 9.581e+00 | PDE(un): 7.968e+00 | BC(un): 1.612e-02 | Data(un): 6.249e-01
#             └─ Grad Norms => Tot: 2.067e+02 | PDE: 1.421e+02 | BC: 1.463e+02 | Data: 0.000e+00
# Epoch 60  | Tot Loss (scaled): 7.760e+00 | PDE(un): 6.855e+00 | BC(un): 9.044e-03 | Data(un): 4.712e-01
#             └─ Grad Norms => Tot: 1.427e+02 | PDE: 1.263e+02 | BC: 6.268e+01 | Data: 0.000e+00
# Epoch 70  | Tot Loss (scaled): 4.768e+00 | PDE(un): 4.331e+00 | BC(un): 4.372e-03 | Data(un): 2.791e-01
#             └─ Grad Norms => Tot: 1.064e+02 | PDE: 8.780e+01 | BC: 5.021e+01 | Data: 0.000e+00
# Epoch 80  | Tot Loss (scaled): 3.924e+00 | PDE(un): 3.614e+00 | BC(un): 3.104e-03 | Data(un): 2.679e-01
#             └─ Grad Norms => Tot: 1.046e+02 | PDE: 8.485e+01 | BC: 4.921e+01 | Data: 0.000e+00
# Epoch 90  | Tot Loss (scaled): 2.982e+00 | PDE(un): 2.744e+00 | BC(un): 2.377e-03 | Data(un): 2.185e-01
#             └─ Grad Norms => Tot: 9.430e+01 | PDE: 8.052e+01 | BC: 3.866e+01 | Data: 0.000e+00
# Epoch 100 | Tot Loss (scaled): 2.952e+00 | PDE(un): 2.563e+00 | BC(un): 3.891e-03 | Data(un): 1.815e-01
#             └─ Grad Norms => Tot: 1.124e+02 | PDE: 6.916e+01 | BC: 7.474e+01 | Data: 0.000e+00
# Epoch 110 | Tot Loss (scaled): 2.354e+00 | PDE(un): 2.171e+00 | BC(un): 1.827e-03 | Data(un): 2.048e-01
#             └─ Grad Norms => Tot: 7.749e+01 | PDE: 6.377e+01 | BC: 3.981e+01 | Data: 0.000e+00
# Epoch 120 | Tot Loss (scaled): 2.356e+00 | PDE(un): 2.269e+00 | BC(un): 8.772e-04 | Data(un): 2.013e-01
#             └─ Grad Norms => Tot: 6.958e+01 | PDE: 6.440e+01 | BC: 2.388e+01 | Data: 0.000e+00
# Epoch 130 | Tot Loss (scaled): 2.142e+00 | PDE(un): 1.956e+00 | BC(un): 1.866e-03 | Data(un): 1.601e-01
#             └─ Grad Norms => Tot: 7.476e+01 | PDE: 5.752e+01 | BC: 4.038e+01 | Data: 0.000e+00
# Epoch 140 | Tot Loss (scaled): 2.084e+00 | PDE(un): 1.826e+00 | BC(un): 2.571e-03 | Data(un): 2.077e-01
#             └─ Grad Norms => Tot: 7.751e+01 | PDE: 5.567e+01 | BC: 4.908e+01 | Data: 0.000e+00
# Epoch 150 | Tot Loss (scaled): 1.965e+00 | PDE(un): 1.830e+00 | BC(un): 1.351e-03 | Data(un): 1.921e-01
#             └─ Grad Norms => Tot: 6.771e+01 | PDE: 5.525e+01 | BC: 3.366e+01 | Data: 0.000e+00
# Epoch 160 | Tot Loss (scaled): 1.819e+00 | PDE(un): 1.693e+00 | BC(un): 1.254e-03 | Data(un): 1.785e-01
#             └─ Grad Norms => Tot: 6.412e+01 | PDE: 5.403e+01 | BC: 3.099e+01 | Data: 0.000e+00
# Epoch 170 | Tot Loss (scaled): 1.597e+00 | PDE(un): 1.411e+00 | BC(un): 1.865e-03 | Data(un): 1.645e-01
#             └─ Grad Norms => Tot: 6.725e+01 | PDE: 4.530e+01 | BC: 4.405e+01 | Data: 0.000e+00
# Epoch 180 | Tot Loss (scaled): 1.338e+00 | PDE(un): 1.175e+00 | BC(un): 1.627e-03 | Data(un): 1.723e-01
#             └─ Grad Norms => Tot: 5.841e+01 | PDE: 3.930e+01 | BC: 4.113e+01 | Data: 0.000e+00
# Epoch 190 | Tot Loss (scaled): 1.396e+00 | PDE(un): 1.287e+00 | BC(un): 1.090e-03 | Data(un): 1.911e-01
#             └─ Grad Norms => Tot: 6.081e+01 | PDE: 4.701e+01 | BC: 3.219e+01 | Data: 0.000e+00
# Epoch 200 | Tot Loss (scaled): 1.424e+00 | PDE(un): 1.287e+00 | BC(un): 1.366e-03 | Data(un): 1.552e-01
#             └─ Grad Norms => Tot: 6.650e+01 | PDE: 4.777e+01 | BC: 3.923e+01 | Data: 0.000e+00
# Epoch 210 | Tot Loss (scaled): 1.270e+00 | PDE(un): 1.207e+00 | BC(un): 6.240e-04 | Data(un): 1.743e-01
#             └─ Grad Norms => Tot: 5.519e+01 | PDE: 4.978e+01 | BC: 1.970e+01 | Data: 0.000e+00
# Epoch 220 | Tot Loss (scaled): 1.217e+00 | PDE(un): 1.180e+00 | BC(un): 3.715e-04 | Data(un): 1.573e-01
#             └─ Grad Norms => Tot: 5.092e+01 | PDE: 4.720e+01 | BC: 1.414e+01 | Data: 0.000e+00
# Epoch 230 | Tot Loss (scaled): 1.098e+00 | PDE(un): 9.551e-01 | BC(un): 1.428e-03 | Data(un): 1.508e-01
#             └─ Grad Norms => Tot: 6.560e+01 | PDE: 4.946e+01 | BC: 3.754e+01 | Data: 0.000e+00
# Epoch 240 | Tot Loss (scaled): 1.012e+00 | PDE(un): 9.869e-01 | BC(un): 2.534e-04 | Data(un): 1.552e-01
#             └─ Grad Norms => Tot: 4.345e+01 | PDE: 4.141e+01 | BC: 1.180e+01 | Data: 0.000e+00
# Epoch 250 | Tot Loss (scaled): 1.028e+00 | PDE(un): 9.312e-01 | BC(un): 9.685e-04 | Data(un): 1.494e-01
#             └─ Grad Norms => Tot: 5.187e+01 | PDE: 3.757e+01 | BC: 3.126e+01 | Data: 0.000e+00
# Epoch 260 | Tot Loss (scaled): 9.830e-01 | PDE(un): 8.811e-01 | BC(un): 1.020e-03 | Data(un): 1.555e-01
#             └─ Grad Norms => Tot: 5.032e+01 | PDE: 3.835e+01 | BC: 2.913e+01 | Data: 0.000e+00
# Epoch 270 | Tot Loss (scaled): 1.075e+00 | PDE(un): 8.822e-01 | BC(un): 1.925e-03 | Data(un): 1.807e-01
#             └─ Grad Norms => Tot: 6.992e+01 | PDE: 4.139e+01 | BC: 5.069e+01 | Data: 0.000e+00
# Epoch 280 | Tot Loss (scaled): 8.352e-01 | PDE(un): 7.619e-01 | BC(un): 7.330e-04 | Data(un): 1.621e-01
#             └─ Grad Norms => Tot: 4.351e+01 | PDE: 3.198e+01 | BC: 2.961e+01 | Data: 0.000e+00
# Epoch 290 | Tot Loss (scaled): 9.118e-01 | PDE(un): 8.694e-01 | BC(un): 4.247e-04 | Data(un): 1.489e-01
#             └─ Grad Norms => Tot: 4.436e+01 | PDE: 3.778e+01 | BC: 1.946e+01 | Data: 0.000e+00
# Epoch 300 | Tot Loss (scaled): 7.650e-01 | PDE(un): 7.464e-01 | BC(un): 1.865e-04 | Data(un): 1.498e-01
#             └─ Grad Norms => Tot: 3.931e+01 | PDE: 3.748e+01 | BC: 9.223e+00 | Data: 0.000e+00
# Epoch 310 | Tot Loss (scaled): 7.688e-01 | PDE(un): 7.185e-01 | BC(un): 5.026e-04 | Data(un): 1.465e-01
#             └─ Grad Norms => Tot: 4.334e+01 | PDE: 3.321e+01 | BC: 2.294e+01 | Data: 0.000e+00
# Epoch 320 | Tot Loss (scaled): 7.221e-01 | PDE(un): 6.626e-01 | BC(un): 5.953e-04 | Data(un): 1.412e-01
#             └─ Grad Norms => Tot: 4.181e+01 | PDE: 3.259e+01 | BC: 2.279e+01 | Data: 0.000e+00
# Epoch 330 | Tot Loss (scaled): 6.734e-01 | PDE(un): 6.288e-01 | BC(un): 4.461e-04 | Data(un): 1.437e-01
#             └─ Grad Norms => Tot: 3.638e+01 | PDE: 2.954e+01 | BC: 1.881e+01 | Data: 0.000e+00
# Epoch 340 | Tot Loss (scaled): 6.498e-01 | PDE(un): 6.095e-01 | BC(un): 4.027e-04 | Data(un): 1.471e-01
#             └─ Grad Norms => Tot: 3.386e+01 | PDE: 2.888e+01 | BC: 1.812e+01 | Data: 0.000e+00
# Epoch 350 | Tot Loss (scaled): 6.439e-01 | PDE(un): 6.327e-01 | BC(un): 1.124e-04 | Data(un): 1.446e-01
#             └─ Grad Norms => Tot: 2.943e+01 | PDE: 2.795e+01 | BC: 7.287e+00 | Data: 0.000e+00
# Epoch 360 | Tot Loss (scaled): 5.873e-01 | PDE(un): 5.625e-01 | BC(un): 2.479e-04 | Data(un): 1.450e-01
#             └─ Grad Norms => Tot: 3.247e+01 | PDE: 2.949e+01 | BC: 1.264e+01 | Data: 0.000e+00
# Epoch 370 | Tot Loss (scaled): 5.749e-01 | PDE(un): 5.251e-01 | BC(un): 4.978e-04 | Data(un): 1.476e-01
#             └─ Grad Norms => Tot: 3.582e+01 | PDE: 2.406e+01 | BC: 2.449e+01 | Data: 0.000e+00
# Epoch 380 | Tot Loss (scaled): 5.385e-01 | PDE(un): 5.111e-01 | BC(un): 2.746e-04 | Data(un): 1.374e-01
#             └─ Grad Norms => Tot: 3.416e+01 | PDE: 2.840e+01 | BC: 1.526e+01 | Data: 0.000e+00
# Epoch 390 | Tot Loss (scaled): 5.337e-01 | PDE(un): 5.165e-01 | BC(un): 1.728e-04 | Data(un): 1.362e-01
#             └─ Grad Norms => Tot: 2.829e+01 | PDE: 2.470e+01 | BC: 1.160e+01 | Data: 0.000e+00
# Epoch 400 | Tot Loss (scaled): 4.905e-01 | PDE(un): 4.776e-01 | BC(un): 1.297e-04 | Data(un): 1.474e-01
#             └─ Grad Norms => Tot: 2.363e+01 | PDE: 2.141e+01 | BC: 9.062e+00 | Data: 0.000e+00
# Epoch 410 | Tot Loss (scaled): 4.338e-01 | PDE(un): 4.227e-01 | BC(un): 1.110e-04 | Data(un): 1.411e-01
#             └─ Grad Norms => Tot: 2.403e+01 | PDE: 2.226e+01 | BC: 8.121e+00 | Data: 0.000e+00
# Epoch 420 | Tot Loss (scaled): 5.040e-01 | PDE(un): 4.886e-01 | BC(un): 1.540e-04 | Data(un): 1.387e-01
#             └─ Grad Norms => Tot: 2.506e+01 | PDE: 2.131e+01 | BC: 1.149e+01 | Data: 0.000e+00
# Epoch 430 | Tot Loss (scaled): 4.835e-01 | PDE(un): 4.627e-01 | BC(un): 2.077e-04 | Data(un): 1.439e-01
#             └─ Grad Norms => Tot: 2.992e+01 | PDE: 2.478e+01 | BC: 1.343e+01 | Data: 0.000e+00
# Epoch 440 | Tot Loss (scaled): 5.218e-01 | PDE(un): 5.107e-01 | BC(un): 1.114e-04 | Data(un): 1.402e-01
#             └─ Grad Norms => Tot: 2.551e+01 | PDE: 2.279e+01 | BC: 9.557e+00 | Data: 0.000e+00
# Epoch 450 | Tot Loss (scaled): 4.063e-01 | PDE(un): 3.945e-01 | BC(un): 1.178e-04 | Data(un): 1.331e-01
#             └─ Grad Norms => Tot: 2.283e+01 | PDE: 2.016e+01 | BC: 9.087e+00 | Data: 0.000e+00
# Epoch 460 | Tot Loss (scaled): 4.190e-01 | PDE(un): 4.126e-01 | BC(un): 6.385e-05 | Data(un): 1.417e-01
#             └─ Grad Norms => Tot: 2.252e+01 | PDE: 2.190e+01 | BC: 5.235e+00 | Data: 0.000e+00
# Epoch 470 | Tot Loss (scaled): 4.154e-01 | PDE(un): 4.072e-01 | BC(un): 8.232e-05 | Data(un): 1.366e-01
#             └─ Grad Norms => Tot: 2.247e+01 | PDE: 2.149e+01 | BC: 6.935e+00 | Data: 0.000e+00
# Epoch 480 | Tot Loss (scaled): 4.147e-01 | PDE(un): 3.989e-01 | BC(un): 1.575e-04 | Data(un): 1.344e-01
#             └─ Grad Norms => Tot: 2.517e+01 | PDE: 2.045e+01 | BC: 1.275e+01 | Data: 0.000e+00
# Epoch 490 | Tot Loss (scaled): 3.749e-01 | PDE(un): 3.677e-01 | BC(un): 7.297e-05 | Data(un): 1.355e-01
#             └─ Grad Norms => Tot: 2.139e+01 | PDE: 1.973e+01 | BC: 7.196e+00 | Data: 0.000e+00
# Epoch 500 | Tot Loss (scaled): 4.230e-01 | PDE(un): 4.065e-01 | BC(un): 1.650e-04 | Data(un): 1.322e-01
#             └─ Grad Norms => Tot: 2.637e+01 | PDE: 2.168e+01 | BC: 1.251e+01 | Data: 0.000e+00
# Epoch 510 | Tot Loss (scaled): 3.290e-01 | PDE(un): 3.237e-01 | BC(un): 5.350e-05 | Data(un): 1.371e-01
#             └─ Grad Norms => Tot: 1.750e+01 | PDE: 1.671e+01 | BC: 4.971e+00 | Data: 0.000e+00
# Epoch 520 | Tot Loss (scaled): 3.900e-01 | PDE(un): 3.814e-01 | BC(un): 8.609e-05 | Data(un): 1.396e-01
#             └─ Grad Norms => Tot: 2.141e+01 | PDE: 1.927e+01 | BC: 7.371e+00 | Data: 0.000e+00
# Epoch 530 | Tot Loss (scaled): 3.473e-01 | PDE(un): 3.418e-01 | BC(un): 5.488e-05 | Data(un): 1.405e-01
#             └─ Grad Norms => Tot: 2.197e+01 | PDE: 2.098e+01 | BC: 4.845e+00 | Data: 0.000e+00
# Epoch 540 | Tot Loss (scaled): 3.747e-01 | PDE(un): 3.670e-01 | BC(un): 7.771e-05 | Data(un): 1.334e-01
#             └─ Grad Norms => Tot: 2.162e+01 | PDE: 1.965e+01 | BC: 7.882e+00 | Data: 0.000e+00
# Epoch 550 | Tot Loss (scaled): 3.743e-01 | PDE(un): 3.672e-01 | BC(un): 7.115e-05 | Data(un): 1.439e-01
#             └─ Grad Norms => Tot: 1.601e+01 | PDE: 1.400e+01 | BC: 7.333e+00 | Data: 0.000e+00
# Epoch 560 | Tot Loss (scaled): 3.367e-01 | PDE(un): 3.312e-01 | BC(un): 5.518e-05 | Data(un): 1.357e-01
#             └─ Grad Norms => Tot: 1.856e+01 | PDE: 1.718e+01 | BC: 6.368e+00 | Data: 0.000e+00
# Epoch 570 | Tot Loss (scaled): 2.887e-01 | PDE(un): 2.810e-01 | BC(un): 7.720e-05 | Data(un): 1.355e-01
#             └─ Grad Norms => Tot: 1.966e+01 | PDE: 1.741e+01 | BC: 7.752e+00 | Data: 0.000e+00
# Epoch 580 | Tot Loss (scaled): 3.443e-01 | PDE(un): 3.387e-01 | BC(un): 5.688e-05 | Data(un): 1.419e-01
#             └─ Grad Norms => Tot: 1.820e+01 | PDE: 1.638e+01 | BC: 6.111e+00 | Data: 0.000e+00
# Epoch 590 | Tot Loss (scaled): 3.777e-01 | PDE(un): 3.717e-01 | BC(un): 6.012e-05 | Data(un): 1.365e-01
#             └─ Grad Norms => Tot: 2.461e+01 | PDE: 2.334e+01 | BC: 6.538e+00 | Data: 0.000e+00

# %%
fig, axes = plt.subplots(1, 4, figsize=(24, 5))

# Plot 1: Overall Total Loss
axes[0].plot(history_total, color='black', linewidth=2)
axes[0].set_yscale('log')
axes[0].set_title('Overall Total Loss (Scaled)', fontsize=14)
axes[0].set_xlabel('Epochs', fontsize=12)
axes[0].grid(True, which="both", ls="-", alpha=0.3)

# Plot 2: PDE Loss
axes[1].plot(history_pde, color='blue', linewidth=2)
axes[1].set_yscale('log')
axes[1].set_title('PDE Loss (Unscaled)', fontsize=14)
axes[1].set_xlabel('Epochs', fontsize=12)
axes[1].grid(True, which="both", ls="-", alpha=0.3)

# Plot 3: BC Loss
axes[2].plot(history_bc, color='green', linewidth=2)
axes[2].set_yscale('log')
axes[2].set_title('Boundary Condition (BC) Loss (Unscaled)', fontsize=14)
axes[2].set_xlabel('Epochs', fontsize=12)
axes[2].grid(True, which="both", ls="-", alpha=0.3)

# Plot 4: Data MSE
axes[3].plot(history_data, color='red', linewidth=2)
axes[3].set_yscale('log')
axes[3].set_title('Data MSE (Unscaled)', fontsize=14)
axes[3].set_xlabel('Epochs', fontsize=12)
axes[3].grid(True, which="both", ls="-", alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# --- Cell 11: Final Inference and Plotting ---

# 1. Solve for the final weights using the entire grid
# We pass the full smoothed arrays (a_flat_smooth, a_x_flat, a_y_flat) 
w_final = solve_w(
    params, x, y, a_flat_smooth, a_x_flat, a_y_flat, 
    x_bc, y_bc, bc_val_array, total_features, chunk_size
)

# 2. Extract features for the entire spatial grid
f_full = f_spatial_vmap(params, x, y)

# 3. Compute the final predicted solution
u_pred_full = jnp.dot(f_full, w_final)

# 4. Reshape for plotting
# We plot the ORIGINAL discontinuous 'a' field to visualize the true boundary constraint
a_plot = a_flat.reshape(nx, ny).T
u_sim_plot = u_flat.reshape(nx, ny).T 
u_pred_plot = u_pred_full.reshape(nx, ny).T

# 5. Render the figures
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
ext = [0, 1, 0, 1]

mesh1 = axes[0].imshow(a_plot, interpolation='bilinear', origin='lower', cmap='rainbow', extent=ext, aspect=1.)
fig.colorbar(mesh1, ax=axes[0])
axes[0].set_title(f'Spatial Field a(x,y) | BC: {bc_sample:.4f}')
axes[0].set_xlabel('x-dim')
axes[0].set_ylabel('y-dim')

mesh2 = axes[1].imshow(u_sim_plot, interpolation='bilinear', origin='lower', cmap='rainbow', extent=ext, aspect=1.)
fig.colorbar(mesh2, ax=axes[1])
axes[1].set_title('Simulation Ground Truth (u)')
axes[1].set_xlabel('x-dim')
axes[1].set_ylabel('y-dim')

mesh3 = axes[2].imshow(u_pred_plot, interpolation='bilinear', origin='lower', cmap='rainbow', extent=ext, aspect=1.)
fig.colorbar(mesh3, ax=axes[2])
axes[2].set_title('Direct Solve Prediction')
axes[2].set_xlabel('x-dim')
axes[2].set_ylabel('y-dim')

plt.tight_layout()
plt.show()

# %%
def plot_jax_spatial_residual(params, w_final, x_grid, y_grid, a_grid, a_x_grid, a_y_grid):
    # Use your existing vmap functions to get derivatives over the full grid
    u_x, u_y, u_xx, u_yy = u_dir_spatial_vmap(params, x_grid, y_grid, w_final)
    laplacian_u = u_xx + u_yy
    
    # Calculate the exact PDE residual
    pde_residual = -(a_x_grid * u_x + a_y_grid * u_y + a_grid * laplacian_u) - beta
    
    # Reshape for plotting
    res_plot = pde_residual.reshape(nx, ny).T
    
    plt.figure(figsize=(7, 6))
    # Using vmin and vmax to catch extremes
    im = plt.imshow(res_plot, interpolation='bilinear', origin='lower', cmap='coolwarm', extent=[0, 1, 0, 1])
    plt.colorbar(im, label='PDE Residual Magnitude')
    plt.title('Spatial Distribution of PDE Residual')
    plt.xlabel('x-dim')
    plt.ylabel('y-dim')
    plt.show()

# Run this right after you calculate w_final in your final cell
plot_jax_spatial_residual(params, w_final, x, y, a_flat_smooth, a_x_flat, a_y_flat)
